# %%
import unittest
import snakestats


# start of function
# mode = find_mode(D)

# if mode!=None:
#     print("got mode")
#     for ele in mode:
#         print(f'number = {ele.number}')
# else:
#     print("there is no mode")
#     print(D)


class elements:
    def __init__(self,number,appear_count):
        self.number =number
        self.appear_count = appear_count
     
    
    
def find_mode(D):
    size = len(D)
    index =0
    mode_list =[]
    
    
    
    max_entry = elements(0,0)
    
    while index<size:
        entry = D[index]

        found=False
        for ele in mode_list:
            if ele.number==entry:
                ele.appear_count = ele.appear_count +1

                if ele.appear_count > max_entry.appear_count:
                    max_entry.number = ele.number
                    max_entry.appear_count = ele.appear_count

                found = True
                break

        if found == False:
            mode_list.append(elements(entry,1))

        index=index+1 
        
        
    num_unique =len(mode_list)
    m_list=[]
    mode_is_available = False
    
    for ele in mode_list:
        if ele.appear_count == max_entry.appear_count:
            m_list.append(ele)
        else:
            mode_is_available = True
    
    if mode_is_available == True:
        return(m_list)
    else:
        return None

    
    
    
    

class TestsForMode(unittest.TestCase):


#first test
    def test_mode_values(self):
        D=[1,2,2,2,3,3,3]
        mode = find_mode(D)
        self.assertEqual(mode, 2)
    
    
    
#second test to test if the input imported returns none because of duplicated number
    def test_mode_similarvalues(self):
        D=[1,2,2,3,3]
        mode = find_mode(D)
        self.assertEqual(mode,3)
        

    
    
    
    
    
    
    
    
    
unittest.main(argv=['ignored', '-v'], exit=False)

# %%
class elements:
    def __init__(self,number,appear_count):
        self.number =number
        self.appear_count = appear_count
     
    
    
def find_mode(D):
    size = len(D)
    index =0
    mode_list =[]
    
    
    
    max_entry = elements(0,0)
    
    while index<size:
        entry = D[index]

        found=False
        for ele in mode_list:
            if ele.number==entry:
                ele.appear_count = ele.appear_count +1

                if ele.appear_count > max_entry.appear_count:
                    max_entry.number = ele.number
                    max_entry.appear_count = ele.appear_count

                found = True
                break

        if found == False:
            mode_list.append(elements(entry,1))

        index=index+1 
        
        
    num_unique =len(mode_list)
    m_list=[]
    mode_is_available = False
    
    for ele in mode_list:
        if ele.appear_count == max_entry.appear_count:
            m_list.append(ele)
        else:
            mode_is_available = True
    
    if mode_is_available == True:
        return(m_list)
    else:
        return None
    
    
    mode = find_mode(D)

    if mode!=None:
        print("got mode")
    for ele in mode:
        print(f'number = {ele.number}')
    else:
        print("there is no mode")
        print(D)

# %% [markdown]
# # THE FINAL WORK

# %%
import unittest
import snakestats


class TestsForMode(unittest.TestCase):
    
    # a simple test that return mode of a list of values
    def test_mode_values(self):
        res = snakestats.mode([1,1,2])
        self.assertEqual(res, 1)
        
    # test for list of many values
    def test_mode_big_values(self):
        res = snakestats.mode([11,11,12,12,13,13,13])
        self.assertEqual(res, 13)
    
    def test_mode_ofdifforder(self):
        res = snakestats.mode([3,1,1,1,2,3,3])
        self.assertEqual(res, 3)
        
class TestsForMedian(unittest.TestCase):
    
    def test_median_oddlength(self):
        med = snakestats.median([1,2,3,4,5])
        self.assertEqual(med, 3)
        
    def test_median_oddlength(self):
        med = snakestats.median([1,2,3,4,5,6])
        self.assertEqual(med, 3.5)
        

    def test_median_unordered(self):
        med = snakestats.median([4,3,5,2,1,6])
        self.assertEqual(med, 3.5)
        
    
class TestsForLowestValue(unittest.TestCase):
    
    def test_getLow(self):
        low = snakestats.getLow([1,2,3,4,5])
        self.assertEqual(low, 1)
    
    def test_getLowatLast(self):
        low = snakestats.getLow([5,4,3,2,1])
        self.assertEqual(low, 1)
        
    def test_getLow_negative(self):
        low = snakestats.getLow([5,4,3,2,1,-1])
        self.assertEqual(low, -1)
    

        


        
unittest.main(argv=['ignored', '-v'], exit=False)

# %%
import unittest
import snakestats

class TestsForMode(unittest.TestCase):
    
#   a simple test that return mode of a list of values
    def test_mode_values(self):
        res = snakestats.mode([1,1,2])
        self.assertEqual(res, 1)
        
#   test for list of many values
    def test_mode_morevalues(self):
        res = snakestats.mode([11,11,12,12,13,13,13])
        self.assertEqual(res, 13)

#   test for list of unordered values
    def test_mode_ofdifforder(self):
        res = snakestats.mode([1,1,3,3])
        self.assertEqual(res, 3)
       


unittest.main(argv=['ignored', '-v'], exit=False)

# %%
def mode (vals):
    
    for x in range(0,len(vals)):
        temp = vals.count(vals[x])
        
        if(temp>1):
            return vals[x]

        
mode([11,11,12,12,13,13,13])

# %%
def mode(vals):
     
        count=0
        temp=0
        index=0
        for x in range(0,len(vals)):
            temp = vals.count(vals[x])
            if(temp>count):
                count = temp
                index = x
           
            
        return vals[index]   
mode([11,11,12,12,13,13,13])

# %%
def getLow(vals):
    
    lowSeen = vals[0]
    for i in range(0,len(vals)):
        if vals[i]<lowSeen :
            lowSeen = vals[i]
    return lowSeen

getLow([1,2,3,-1])

# %%
def median(vals):
    n = len(vals)
    
    #add this to unordered
    vals.sort()


# check if even or odd with modulus
    if n % 2 != 0:
        middle = int((n-1)/2)
        return vals[middle]
# this is for even length we need to add the item from previous to add up to get middle 
    elif n%2 == 0:
        middle1 = int(n/2)
        middle2=int(n/2)-1
        
        return (vals[middle1]+vals[middle2])/2

# %%
#input is 1,1,3,3
def mode(vals):
        
        count=0
        temp=0
        index=0
        for x in range(0,len(vals)):
            temp = vals.count(vals[x]) # [1,1,2,2] checks frequency of each element
            
            if(temp>count):
                count = temp
                index = x 
        
        return vals[index]

# %%
def find_mode(list_n):
    #let convert list into sets so no duplicates
    new_set = set(list_n)
    new_list = list(new_set)
    counts = []
    
#1,2 only so loop 2 times
    for i in range(len(new_list)):
        
        #count number 1 and 2,pass in list_n
        #list is append to each other 
        #so 3 count for number1 and 3 counts for number2 so [3,3]
        
        counts += [list_n.count(new_list[i])]
        
      
    #max of [3,3] is 3
    max_count = max(counts)
   
    #get index in [3,3] which element has the max count 3
    #index [0] and [1] has 3
    index = counts.index(max_count)
    
    a=new_list[index];
    
    
   
    #index now is 0+1 so "1" , range to , lenofcounts is "2" because [3],[3,3]
    for i in range(index+1,len(counts)):

        if(max_count == counts[i]):
            b=new_list[i]
            return [a]+[b]
        
    
    return [a]


#calling function
find_mode(list_n)






import unittest
class TestsForMode(unittest.TestCase):
    
#   a simple test that return mode of a list of values
    def test_mode_values(self):
        res = find_mode([1,1,2])
        self.assertEqual(res, [1])
        
#   test for list of many values
    def test_mode_morevalues(self):
        res = find_mode([11,11,12,12,13,13,13])
        self.assertEqual(res, [13])
        



unittest.main(argv=['ignored', '-v'], exit=False)

# %%
# def find_mode(list_n):
    
#     #empty list to store values
#     for i in range(len(list_n)):

#             #count number 1 and 2,pass in counts
#             a = list_n.count(list_n[i])
            
#             #find the maximum count 
#             max_count = max(counts)

#         #get index which element has the max count
#             index = counts.index(max_count)
#             a=list_n[index];

#     return [a]

#=========================
def find_mode(mylist):
    
    #empty list to store values
    counts=[]
    for i in range(len(mylist)):

            #count number 1 and 2,pass in counts
            counts += [mylist.count(mylist[i])]
            
            #find the maximum count 
            max_count = max(counts)

        #get index which element has the max count
            index = counts.index(max_count)
            a=mylist[index];

    return [a]

import unittest
class TestsForMode(unittest.TestCase):
    
#   a simple test that return mode of a list of values
    def test_mode_valuecounts(self):
        res = find_mode([1,1,2,2,2])
        self.assertEqual(res, 3)
        
    #   test for list of many values
    def test_mode_morevalues(self):
        res = find_mode([11,11,12,12,13,13,13])
        self.assertEqual(res, [13])
        
        


unittest.main(argv=['ignored', '-v'], exit=False)

# %%
import unittest
import snakestats
class TestsForMode(unittest.TestCase):
    
    # a simple test that return value counts of mode element
    # Example : mode element 2 returns 3 value counts
    
    def test_mode_valuecounts(self):
        res = snakestats.find_count([1,1,2,2,2])
        self.assertEqual(res, 3)
    
    #test to find mode value
    
    def test_mode_returnmode(self):
        res = snakestats.find_mode([11,11,12,12,13,13,13])
        self.assertEqual(res, [13])
        
    
            
    #   test for similar mode values
    def test_mode_similarmode(self):
        res = snakestats.find_mode([1,1,3,3])
        self.assertEqual(res, [1,3])
       
        

        
unittest.main(argv=['ignored', '-v'], exit=False)

# %%
import unittest
import snakestats

class TestsForMedian(unittest.TestCase):
    
    #test median for list of odd length
    def test_median_oddlength(self):
        med = snakestats.median([1,2,3,4,5])
        self.assertEqual(med, 3)
    
    #test median for list of even
    def test_median_evenlength(self):
        med = snakestats.median([1,2,3,4,5,6])
        self.assertEqual(med, 3.5)
        
    #test median for unordered elements
    def test_median_unordered(self):
        med = snakestats.median([4,2,5,3,1,6])
        self.assertEqual(med, 3.5)

unittest.main(argv=['ignored', '-v'], exit=False)

# %%
def getLow(vals):
    
    lowSeen = vals[0]
    for i in range(0,len(vals)): 
        
       
        if vals[i]<lowSeen:
            lowSeen = vals[i]
            
        if vals[i]<0:
            raise ValueError("The number cannot be negative")
            
       
        
        
#         if type(vals[i]) not in [int,float]:
#             raise TypeError("The input value must be positive interger or float")
            
       
            
    return lowSeen


import unittest
import snakestats

class TestsForLowest_Positivenumber(unittest.TestCase):
    
    #get lowest value 
    def test_getLow(self):
        low = getLow([1,2,3,4,5])
        self.assertEqual(low, 1)
        
    #test if function show error if wrong value is inserted
    def test_getLow_wrongvalue(self):
        self.assertRaises(ValueError,getLow,[-1])
    
    
    #test if input error(of different type e.g string,boolean) are raised
    def test_getLow_inputwrong(self):
        self.assertRaises(TypeError,getLow,["not a number"])
        self.assertRaises(TypeError,getLow,[True])
    
    
unittest.main(argv=['ignored', '-v'], exit=False)
# Out:
# test_getLow (__main__.TestsForLowest_Positivenumber) ... ok
# test_getLow_inputwrong (__main__.TestsForLowest_Positivenumber) ... FAIL
# test_getLow_wrongvalue (__main__.TestsForLowest_Positivenumber) ... ok
#
# ...
# FAIL: test_getLow_inputwrong (__main__.TestsForLowest_Positivenumber)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\yingjie\AppData\Local\Temp\ipykernel_24996\4192666336.py", line 42, in test_getLow_inputwrong
#     self.assertRaises(TypeError,getLow,[True])
# AssertionError: TypeError not raised by getLow
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.006s
#
# FAILED (failures=1)

# %%
import unittest
import snakestats
class TestsForLowest_Positivenumber(unittest.TestCase):
    
    #get lowest value 
    def test_getLow(self):
        low = snakestats.getLow([1,2,3,4,5])
        self.assertEqual(low, 1)
    
    #test if function show error if wrong value is inserted
    def test_getLow_wrongvalue(self):
        self.assertRaises(ValueError,snakestats.getLow,[-1])
        
    #test if error of input types is raised
    def test_getLow_wronginputtype(self):
        self.assertRaises(TypeError,snakestats.getLow,"not a number")
        self.assertRaises(TypeError,snakestats.getLow,[True])

    
unittest.main(argv=['ignored', '-v'], exit=False)
# Out:
# test_getLow (__main__.TestsForLowest_Positivenumber) ... ok
# test_getLow_wronginputtype (__main__.TestsForLowest_Positivenumber) ... ok
# test_getLow_wrongvalue (__main__.TestsForLowest_Positivenumber) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.009s
#
# OK

# %% [markdown]
# ## THIS IS THE SAMPLE OF EDITED SNAKESTATS

# %%
def find_count(mylist):
    counts=[]
    for i in range(len(mylist)):

            #count number 1 and 2,pass in counts
            counts += [mylist.count(mylist[i])]
            
            #find the maximum count 
            max_count = max(counts)

    return max_count

    
    
    
# def find_mode(mylist):

#     #empty list to store values
#     counts=[]
#     for i in range(len(mylist)):

#             #count number 1 and 2,pass in counts
#             counts += [mylist.count(mylist[i])]

#             #find the maximum count 
#             max_count = max(counts)

#         #get index which element has the max count
#             index = counts.index(max_count)
#             a=mylist[index];

#     return [a]
    
    

    
def find_mode(mylist):
    #let convert list into sets so no duplicates
    myset = set(mylist)
    my_newlist = list(myset)
    counts = []
    
    for i in range(len(my_newlist)):
        
        counts += [mylist.count(my_newlist[i])]
        
      
    max_count = max(counts)
    index = counts.index(max_count)
    
    a=my_newlist[index];
    
    #this gets the other similar mode 
    for i in range(index+1,len(counts)):

        if(max_count == counts[i]):
            b=my_newlist[i]
            return [a]+[b]
        
    
    return [a]


    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
#===========================================================
# def mode (vals):
#     for x in range(0,len(vals)):
#         temp = vals.count(vals[x])
        
#         if(temp>1):
#             return vals[x] 
 

# enhance the function with counters to find mode
#input is 1,1,3,3
# def mode(vals):
        
#         count=0
#         temp=0
#         index=0
#         for x in range(0,len(vals)):
#             temp = vals.count(vals[x]) # 2,3
#             if(temp>count):
#                 count = temp
#                 index = x
                
                
            
#         return vals[index]   





def getLow(vals):
    
    lowSeen = vals[0]
    for i in range(0,len(vals)): 
        
        if vals[i]<0:
            raise ValueError("The number cannot be negative")
            
        if vals[i]<lowSeen:
            lowSeen = vals[i]
            
        if type(vals[i]) not in [int,float]:
            raise TypeError("The input value must be positive interger or float")
            
       

            
    return lowSeen          


            












def median(vals):
    n = len(vals)
    
    #add this to unordered
    vals.sort()
    
    # check if odd
    if n % 2 != 0:
        middle = int((n-1)/2)
        return vals[middle]
    
    # this is for even length we need to add the item from previous to add up to get middle 
    elif n%2 == 0:
        middle1 = int(n/2)
        middle2=int(n/2)-1
        
        return (vals[middle1]+vals[middle2])/2













# def median(vals):
#     n = len(vals)
    

#     vals.sort()


# # check if even or odd with modulus
#     if n % 2 != 0:
#         middle = int((n-1)/2)
#         return vals[middle]
# # this is for even length we need to add the item from previous to add up to get middle 
#     elif n%2 == 0:
#         middle1 = int(n/2)
#         middle2=int(n/2)-1
        
#         return (vals[middle1]+vals[middle2])/2

# %%
THIS IS LAST
